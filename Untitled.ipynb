# %%
from hanabi.game_field import GameField
from hanabi.players import Player, RandomPlayer, NaiveRuleBasedPlayer


game = GameField()

# %%
game.setup_game([NaiveRuleBasedPlayer(0), NaiveRuleBasedPlayer(1), NaiveRuleBasedPlayer(2), NaiveRuleBasedPlayer(3)])
game.auto_play()
# Out:
# ...
# Deck: 30
# Hint Tokens: [○○○○○○○○]
# Failure Tokens: []
#
# Hanabi Field:
# R: []
# B: []
# Y: []
# G: []
# W: []
#
# Hand:
# Player 0:
# ['B1', 'G4', 'W4', 'Y1', 'R1']
#
# Player 1:
# ['W5', 'W4', 'Y5', 'R3', 'B3']
#
# Player 2:
# ['G2', 'W1', 'B2', 'B1', 'G2']
#
# Player 3:
# ['R4', 'Y2', 'R1', 'Y4', 'Y3']
#
# ...
#
# Player 0's action: GiveColorHint(2ForBLUE)
# ...
# Deck: 30
# Hint Tokens: [○○○○○○○]
# Failure Tokens: []
#
# Hanabi Field:
# R: []
# B: []
# Y: []
# G: []
# W: []
#
# Hand:
# Player 0:
# ['B1', 'G4', 'W4', 'Y1', 'R1']
#
# Player 1:
# ['W5', 'W4', 'Y5', 'R3', 'B3']
#
# Player 2:
# ['G2', 'W1', 'B2', 'B1', 'G2']
#
# Player 3:
# ['R4', 'Y2', 'R1', 'Y4', 'Y3']
#
# ...
#
# Player 1's action: GiveColorHint(2ForBLUE)
# ...
# Deck: 30
# Hint Tokens: [○○○○○○]
# Failure Tokens: []
#
# Hanabi Field:
# R: []
# B: []
# Y: []
# G: []
# W: []
#
# Hand:
# Player 0:
# ['B1', 'G4', 'W4', 'Y1', 'R1']
#
# Player 1:
# ['W5', 'W4', 'Y5', 'R3', 'B3']
#
# Player 2:
# ['G2', 'W1', 'B2', 'B1', 'G2']
#
# Player 3:
# ...

# %%
print(game)
# Out:
# ...
# Deck: 35
# Hint Tokens: [○○○○○○○○]
# Failure Tokens: []
#
# Hanabi Field:
# R: []
# B: []
# Y: []
# G: []
# W: []
#
# Hand:
# Player 0:
# ['B3', 'W3', 'R2', 'Y1', 'W1']
#
# Player 1:
# ['W5', 'R1', 'Y2', 'Y3', 'G3']
#
# Player 2:
# ['R4', 'R5', 'W1', 'B3', 'Y3']
#
# ...

# %%
# Out:
# ...
# Deck: 27
# Hint Tokens: [○○]
# Failure Tokens: [●●●]
#
# Hanabi Field:
# R: [1, 2, 3]
# B: []
# Y: [1]
# G: []
# W: [1]
#
# Hand:
# Player 0:
# ['B3', 'W3', 'W1', 'W2', 'G2']
#
# Player 1:
# ['W5', 'G3', 'W4', 'B1', 'G1']
#
# Player 2:
# ['R4', 'R5', 'B3', 'Y3', 'R4']
#
# ...
#
# Player 0's action: GiveColorHint(1ForBLUE)
# ...
# Deck: 27
# Hint Tokens: [○]
# Failure Tokens: [●●●]
#
# Hanabi Field:
# R: [1, 2, 3]
# B: []
# Y: [1]
# G: []
# W: [1]
#
# Hand:
# Player 0:
# ['B3', 'W3', 'W1', 'W2', 'G2']
#
# Player 1:
# ['W5', 'G3', 'W4', 'B1', 'G1']
#
# Player 2:
# ['R4', 'R5', 'B3', 'Y3', 'R4']
#
# ...
# 5

# %%
observation = game.get_current_player_observation()

# %%
from typing import List, Dict
from hanabi.objects import (
    FailureTokensOnField,
    HintTokensOnField,
    Deck,
    Card,
    Color,
    Rank,
)
from hanabi.hanabi_field import HanabiField
from hanabi.players import Player, CardHint

# %%
from hanabi.actions import Action, GetHintToken, PlayCard

PlayCard(3) == PlayCard(3)
# Out:
# True

# %%
find_playable_card_for_other(player_observation)
# Out:
# (2, Card(color=<Color.RED: 'R'>, rank=<Rank.ONE: 1>))
