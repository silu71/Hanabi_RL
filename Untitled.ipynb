# %%
from hanabi.game_field import GameField

game = GameField(2)

# %%
game.start_game()
# Out:
# ...
# Deck: 40
# Hint Tokens: [○○○○○○○○]
# Failure Tokens: []
#
# Hanabi Field:
# R: []
# B: []
# Y: []
# G: []
# W: []
#
# Hand:
# Player 0:
# ['B1', 'Y4', 'B2', 'B4', 'R3']
#
# Player 1:
# ['W1', 'B3', 'G1', 'B2', 'R1']
#
# ...
#
# Valid actions
# ['Play0', 'Play1', 'Play2', 'Play3', 'Play4', 'ColorHintTo1ForR', 'ColorHintTo1ForB', 'ColorHintTo1ForG', 'ColorHintTo1ForW', 'RankHintTo1For1', 'RankHintTo1For2', 'RankHintTo1For3']
# Input action: Play1
# ...
# Deck: 39
# Hint Tokens: [○○○○○○○○]
# Failure Tokens: [●]
#
# Hanabi Field:
# R: []
# B: []
# Y: []
# G: []
# W: []
#
# Hand:
# Player 0:
# ['B1', 'B2', 'B4', 'R3', 'R3']
#
# Player 1:
# ['W1', 'B3', 'G1', 'B2', 'R1']
#
# ...
#
# Valid actions
# ['Play0', 'Play1', 'Play2', 'Play3', 'Play4', 'ColorHintTo0ForR', 'ColorHintTo0ForB', 'RankHintTo0For1', 'RankHintTo0For2', 'RankHintTo0For3', 'RankHintTo0For4']
# Input action: Play0
# ...
# Deck: 38
# Hint Tokens: [○○○○○○○○]
# Failure Tokens: [●]
#
# Hanabi Field:
# R: []
# B: []
# Y: []
# G: []
# W: [1]
#
# Hand:
# ...

# %%
game.distribute_cards()

# %%
print(game)
# Out:
# Deck: 40
# Hint Tokens: [○○○○○○○○]
# Failure Tokens: []
#
# Hanabi Field:
# R: []
# B: []
# Y: []
# G: []
# W: []
#
# Hand:
# Player 0:
# ['G2', 'W2', 'Y1', 'Y4', 'G1']
#
# Player 1:
# ['R2', 'B1', 'B2', 'R1', 'Y5']
